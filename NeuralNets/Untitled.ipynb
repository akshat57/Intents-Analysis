# %%
import matplotlib.pyplot as plt

# %%
ratio = [0, 0.05, 0.1, 0.15, 0.2, 0.25]

HGM_B = [80.67, 80.67, 85, 88, 88.67, 89.34]
HGB_M = [61.67, 70.0, 75.34, 75, 76.67, 76.34]
HMB_G = [62, 78.67, 83.34, 82, 84.34, 85]
GMB_H = [65.3, 78.34, 79.34, 80, 80, 82.34]

hgm_b = [58.34, 81.34, 84.34, 85.67, 85.67, 85.67]
hgb_m = [54.34, 66.34, 72.67, 75.34, 73.67, 76.67]
hmb_g = [65.34, 76.67, 78.67, 76.67, 76, 80.67 ]
gmb_h = [63.67, 76.67, 79.67, 80.34, 80.67, 82.67]

# %%
fig = plt.figure(figsize = (7,5))
plt.plot(ratio, HGM_B, '-y*')
plt.plot(ratio, HGB_M, '-c*')
plt.plot(ratio, HMB_G, '-m*')
plt.plot(ratio, GMB_H, '-g*')
#plt.plot(ratio, hgm_b, '--.y')
#plt.plot(ratio, hgb_m, '--.c')
#plt.plot(ratio, hmb_g, '--.m')
#plt.plot(ratio, gmb_h, '--.g')
plt.xlabel('Ratio of Unkown Language ($L_u$) data in Training Dataset', fontsize = 12 )
plt.ylabel('Classification Accuracy for $L_u$', fontsize = 12 )
plt.legend(['HGM -> B', 'HGB -> M', 'HMB -> G', 'GMB -> H'], fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.savefig('variation.png')
